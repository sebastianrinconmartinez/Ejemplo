# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastianrinconmartinez/Ejemplo/blob/master/Notebook_ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Este es un ejemplo**

# %%
print("Hello World")
# Out:
# Hello World
